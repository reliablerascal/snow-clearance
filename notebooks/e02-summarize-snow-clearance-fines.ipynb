# %% [markdown]
# <h1>Snow Clearance Fines, 2019-2023</h1>
# 31 January 2024
#
# This analysis looks at fines levied for uncleared sidewalks, based on FOIA data requested from the Department of Administrative Hearings (H064920-011124.xlsx). This dataset contained 3058 records dating from 1/1/2001 to 9/12/2023. Looking at only records between 7/1/2019 and 6/30/2023, we have 2560 records.<br>
# <br>
# My analysis steps:
# <ol>
# <li><a href="#read">Read Data</a>
# <li><a href="#prep">Prepare Data</a>- label by season, etc.
#     <li><a href="#summarize">Summarize</a>- by issuing department, by year, by community area
# </ol>

# %% [markdown]
# <div style="color:red;">
#     <h3>Preliminary Findings</h3>
# <ul>
#     <li>I'm looking at an old version of the geocoded fines dataset, to get started. Will use updated dataset when it's ready. Should have about 2556 records.
# </ul>
#     </div>

# %% [markdown]
# <a name="read"></a>
# # 1. Read Data

# %%
import pandas as pd
import requests
#import datetime as dt #would only need this if I manipulated dates post-API data retrieval

# %%
df = pd.read_csv("../data/old_fines-geocoded-communities.csv")
df.head()
# Out:
#   Docket Number Violation Date Violation Address     City State  \
# 0    18CP093079     2018-11-27      5045 N TRIPP  Chicago    IL
# 1    19CP003510     2019-01-16      5045 N TRIPP  Chicago    IL
# 2    19CP009688     2019-02-13      5045 N TRIPP  Chicago    IL
# 3    21DT000885     2021-02-19   3859 W LAWRENCE  Chicago    IL
# 4    21DT000885     2021-02-19   3859 W LAWRENCE  Chicago    IL
#
#   Issuing Department Code Imposed Fine Detailed  result_num     osm_id  \
# 0                  POLICE                 $0.00           0  162465502
# 1                  POLICE                 $0.00           0  162465502
# 2                  POLICE                 $0.00           0  162465502
# 3                TRANPORT                 $0.00           0   34319057
# 4                TRANPORT               $110.00           0   34319057
#
#                                         display_name  ...  \
# 0  5045, North Tripp Avenue, Mayfair, Albany Park...  ...
# 1  5045, North Tripp Avenue, Mayfair, Albany Park...  ...
# 2  5045, North Tripp Avenue, Mayfair, Albany Park...  ...
# 3  3859, West Lawrence Avenue, Albany Park, Chica...  ...
# 4  3859, West Lawrence Avenue, Albany Park, Chica...  ...
#
#                                 latlong    community area   shape_area  \
# 0               41.9731502,-87.73406095  ALBANY PARK  0.0  53542230.82
# 1               41.9731502,-87.73406095  ALBANY PARK  0.0  53542230.82
# 2               41.9731502,-87.73406095  ALBANY PARK  0.0  53542230.82
# 3  41.96819227184388,-87.72489666413433  ALBANY PARK  0.0  53542230.82
# 4  41.96819227184388,-87.72489666413433  ALBANY PARK  0.0  53542230.82
#
#    perimeter  area_num_1  area_numbe  comarea_id  comarea    shape_len
# 0        0.0        14.0        14.0         0.0      0.0  39339.01644
# 1        0.0        14.0        14.0         0.0      0.0  39339.01644
# 2        0.0        14.0        14.0         0.0      0.0  39339.01644
# 3        0.0        14.0        14.0         0.0      0.0  39339.01644
# 4        0.0        14.0        14.0         0.0      0.0  39339.01644
#
# [5 rows x 22 columns]

# %%
len(df)
# Out:
# 2883

# %% [markdown]
# <a name="prepare"></a>
# # 3. Prepare Data

# %% [markdown]
# ### remove records with missing violation dates

# %%
# find records with missing Violation Date. NaT means "Not a Time"
df[df['Violation Date'].isna()]
# Out:
# Empty DataFrame
# Columns: [Docket Number, Violation Date, Violation Address, City, State, Issuing Department Code, Imposed Fine Detailed]
# Index: []

# %%
df_clean = df[df['Violation Date'].notna()]
len(df_clean)
# Out:
# 2560

# %% [markdown]
# ### parse dates

# %%
def get_season(month, year):
# Input:
#   month: numeric month of the year (1-12)
#   year (int): 4 digit year
# Returns:
#   season in yy-yy format. E.g. 22-23 means winter 2022-2023, or July 2022 to June 2023.

    if month >= 7:
        return f"{str(year)[-4:]}-{str(year + 1)[-4:]}"
    else:
        return f"{str(year - 1)[-4:]}-{str(year)[-4:]}"

# %%
# format and parse dates
df['Violation Date'] = pd.to_datetime(df['Violation Date'])
df['year'] = df['Violation Date'].dt.year
df['month'] = df['Violation Date'].dt.month
df['date'] = df['Violation Date'].dt.date
df['season'] = df.apply(lambda row: get_season(row['month'], row['year']), axis=1)
df['Imposed Fine Detailed'] = pd.to_numeric(df['Imposed Fine Detailed'].replace('[\$,]', '', regex=True), errors='coerce')
df.head()
# Out:
#     Docket Number Violation Date      Violation Address  \
# 494    19DT005843     2019-08-08      1615 N FAIRFIELD
# 495    19DT005843     2019-08-08      1615 N FAIRFIELD
# 496    20DT001152     2019-09-05  1717 N HUMBOLDT BLVD
# 497    20DT001152     2019-09-05  1717 N HUMBOLDT BLVD
# 498    20DT001152     2019-09-05  1717 N HUMBOLDT BLVD
#
#     Issuing Department Code  Imposed Fine Detailed  year  month        date  \
# 494                TRANPORT                    0.0  2019      8  2019-08-08
# 495                TRANPORT                  200.0  2019      8  2019-08-08
# 496                TRANPORT                    0.0  2019      9  2019-09-05
# 497                TRANPORT                  500.0  2019      9  2019-09-05
# 498                TRANPORT                 1000.0  2019      9  2019-09-05
#
#         season
# 494  2019-2020
# 495  2019-2020
# 496  2019-2020
# 497  2019-2020
# 498  2019-2020

# %% [markdown]
# ### look at just full years

# %%
df = df[(df['season'].isin(['2019-2020','2020-2021','2021-2022','2022-2023']))]
len(df)
# Out:
# 2560

# %% [markdown]
# <a name="summarize"></a>
# # 4. Summarize Data

# %%
# by season
df.groupby('season').agg(
    sum_fine_amt=('Imposed Fine Detailed', 'sum'),
    n_fines=('Docket Number','nunique')
).reset_index()
# Out:
#       season  sum_fine_amt  n_fines
# 0  2019-2020       96640.0      357
# 1  2020-2021      243510.0      764
# 2  2021-2022      214349.0      700
# 3  2022-2023       31570.0       96

# %%
# by issuing department
df.groupby('Issuing Department Code').agg(
    sum_fine_amt=('Imposed Fine Detailed', 'sum'),
    n_fines=('Docket Number','nunique')
).reset_index()
# Out:
#   Issuing Department Code  sum_fine_amt  n_fines
# 0                 BAFCONP           0.0        2
# 1                  POLICE        1700.0       25
# 2                 STRTSAN      176610.0      497
# 3                TRANPORT      407759.0     1393

# %% [markdown]
# <a name="appendix"></a>
# # Appendix

# %% [markdown]
# ### read community population

# %%
# retrieved on 1/11/24, but 2020 Census Population figures should be static

df_population = pd.read_csv("../data/population_cmap_2022.csv")

# %%
# simplify dataframe to get only essentials
df_population = df_population[['GEOID','GEOG','2020_POP']]
df_population = df_population.rename(columns={'GEOG':'COMMUNITY_NAME'})
df_population['COMMUNITY_CAPS']=df_population['COMMUNITY_NAME'].str.upper()
df_population.head()
# Out:
#    GEOID  COMMUNITY_NAME  2020_POP  COMMUNITY_CAPS
# 0     14     Albany Park     48396     ALBANY PARK
# 1     57  Archer Heights     14196  ARCHER HEIGHTS
# 2     34   Armour Square     13890   ARMOUR SQUARE
# 3     70         Ashburn     41098         ASHBURN
# 4     71  Auburn Gresham     44878  AUBURN GRESHAM

# %% [markdown]
# <a name="ward"></a>
# # 2. By Community Area by 311 Type, 2019-2023

# %%
df_community_by_type = df.pivot_table(index='COMMUNITY_NAME', columns='SR_TYPE', values='SR_NUMBER', aggfunc='size', fill_value=0)
df_community_by_type
# Out:
# SR_TYPE         Ice and Snow Removal Request  \
# COMMUNITY_NAME
# Albany Park                              540
# Archer Heights                           205
# Armour Square                             65
# Ashburn                                 1506
# Auburn Gresham                          1449
# ...                                      ...
# West Lawn                                248
# West Pullman                             752
# West Ridge                               505
# West Town                               1029
# Woodlawn                                 402
#
# SR_TYPE         Snow - Object/Dibs Removal Request  \
# COMMUNITY_NAME
# Albany Park                                    195
# Archer Heights                                 253
# Armour Square                                   52
# Ashburn                                         75
# Auburn Gresham                                 179
# ...                                            ...
# West Lawn                                      434
# West Pullman                                    16
# West Ridge                                     200
# West Town                                      304
# Woodlawn                                        40
#
# SR_TYPE         Snow Removal - Protected Bike Lane or Bridge Sidewalk  \
# COMMUNITY_NAME
# Albany Park                                                    16
# Archer Heights                                                  0
# Armour Square                                                  16
# Ashburn                                                         1
# Auburn Gresham                                                  1
# ...                                                           ...
# West Lawn                                                       0
# West Pullman                                                    0
# West Ridge                                                      5
# West Town                                                      34
# Woodlawn                                                        0
#
# SR_TYPE         Snow – Uncleared Sidewalk Complaint
# COMMUNITY_NAME
# Albany Park                                     400
# Archer Heights                                   60
# Armour Square                                    77
# Ashburn                                         108
# Auburn Gresham                                  128
# ...                                             ...
# West Lawn                                       146
# West Pullman                                     23
# West Ridge                                      804
# West Town                                      1609
# Woodlawn                                        120
#
# [77 rows x 4 columns]

# %% [markdown]
# ### merge in community data

# %%
df_community_summary = pd.merge(left=df_community_by_type,right=df_population,on='COMMUNITY_NAME')
df_community_summary.head()
# Out:
#    COMMUNITY_NAME  Ice and Snow Removal Request  \
# 0     Albany Park                           540
# 1  Archer Heights                           205
# 2   Armour Square                            65
# 3         Ashburn                          1506
# 4  Auburn Gresham                          1449
#
#    Snow - Object/Dibs Removal Request  \
# 0                                 195
# 1                                 253
# 2                                  52
# 3                                  75
# 4                                 179
#
#    Snow Removal - Protected Bike Lane or Bridge Sidewalk  \
# 0                                                 16
# 1                                                  0
# 2                                                 16
# 3                                                  1
# 4                                                  1
#
#    Snow – Uncleared Sidewalk Complaint  GEOID  2020_POP  COMMUNITY_CAPS
# 0                                  400     14     48396     ALBANY PARK
# 1                                   60     57     14196  ARCHER HEIGHTS
# 2                                   77     34     13890   ARMOUR SQUARE
# 3                                  108     70     41098         ASHBURN
# 4                                  128     71     44878  AUBURN GRESHAM

# %%
# per 10,000 capita, per year over 4 years
df_community_summary['Streets Per 10k'] = \
(10000/4)*df_community_summary['Ice and Snow Removal Request']/df_community_summary['2020_POP']

df_community_summary['Dibs Per 10k'] = \
(10000/4)*df_community_summary['Snow - Object/Dibs Removal Request']/df_community_summary['2020_POP']

df_community_summary['Sidewalks Per 10k'] = \
(10000/4)*df_community_summary['Snow – Uncleared Sidewalk Complaint']/df_community_summary['2020_POP']

df_community_summary['Bike-Bridge Per 10k'] = \
(10000/4)*df_community_summary['Snow Removal - Protected Bike Lane or Bridge Sidewalk']/df_community_summary['2020_POP']

# %%
df_community_summary.head()
# Out:
#    COMMUNITY_NAME  Ice and Snow Removal Request  \
# 0     Albany Park                           540
# 1  Archer Heights                           205
# 2   Armour Square                            65
# 3         Ashburn                          1506
# 4  Auburn Gresham                          1449
#
#    Snow - Object/Dibs Removal Request  \
# 0                                 195
# 1                                 253
# 2                                  52
# 3                                  75
# 4                                 179
#
#    Snow Removal - Protected Bike Lane or Bridge Sidewalk  \
# 0                                                 16
# 1                                                  0
# 2                                                 16
# 3                                                  1
# 4                                                  1
#
#    Snow – Uncleared Sidewalk Complaint  GEOID  2020_POP  COMMUNITY_CAPS  \
# 0                                  400     14     48396     ALBANY PARK
# 1                                   60     57     14196  ARCHER HEIGHTS
# 2                                   77     34     13890   ARMOUR SQUARE
# 3                                  108     70     41098         ASHBURN
# 4                                  128     71     44878  AUBURN GRESHAM
#
#    Streets Per 10k  Dibs Per 10k  Sidewalks Per 10k  Bike-Bridge Per 10k
# 0        27.894867     10.073147          20.662865             0.826515
# 1        36.101719     44.554804          10.566357             0.000000
# 2        11.699064      9.359251          13.858891             2.879770
# 3        91.610297      4.562266           6.569663             0.060830
# 4        80.718838      9.971478           7.130443             0.055707

# %%
df_community_summary.to_csv("../results/311_community_by_type.csv", index=False)

# %% [markdown]
# # 3. Summary Stats for Uncleared Sidewalk Complaints

# %%
# remove incomplete seasons, 2018-2019 and 2023-2024
df_uncleared = df[(df['SR_SHORT_CODE']=='SWSNOREM') & (df['season'].isin(['2019-2020','2020-2021','2021-2022','2022-2023']))]
len(df_uncleared)
# Out:
# 21079

# %% [markdown]
# ### uncleared by season

# %%
df_by_season = df_uncleared.groupby('season').agg(complaints=('SR_NUMBER','count')).reset_index()
df_by_season
# Out:
#       season  complaints
# 0  2019-2020        6541
# 1  2020-2021        6494
# 2  2021-2022        6416
# 3  2022-2023        1628

# %% [markdown]
# ### uncleared by type

# %%
df_by_type = df_uncleared.groupby('ORIGIN').agg(complaints=('SR_NUMBER','count')).reset_index()
df_by_type
# Out:
#                        ORIGIN  complaints
# 0           Alderman's Office         724
# 1                      E-Mail          22
# 2          Generated In House           1
# 3                    Internet        7068
# 4               Mobile Device        8260
# 5           Open311 Interface           1
# 6                  Phone Call        4818
# 7       Salesforce Mobile App          36
# 8  spot-open311-Chicago+Works          97
# 9    spot-open311-SeeClickFix          52

# %%
# consolidate other
df_uncleared['MODIFIED_ORIGIN'] = df_uncleared['ORIGIN'].replace(['E-Mail', 'Generated In House', 'Open311 Interface','Salesforce Mobile App','spot-open311-Chicago+Works','spot-open311-SeeClickFix'], 'Other')
# Out:
# /tmp/ipykernel_2099/2302404863.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_uncleared['MODIFIED_ORIGIN'] = df_uncleared['ORIGIN'].replace(['E-Mail', 'Generated In House', 'Open311 Interface','Salesforce Mobile App','spot-open311-Chicago+Works','spot-open311-SeeClickFix'], 'Other')

# %%
df_by_type = df_uncleared.groupby('MODIFIED_ORIGIN').agg(complaints=('SR_NUMBER','count')).reset_index()
df_by_type
# Out:
#      MODIFIED_ORIGIN  complaints
# 0  Alderman's Office         724
# 1           Internet        7068
# 2      Mobile Device        8260
# 3              Other         209
# 4         Phone Call        4818

# %% [markdown]
# ### uncleared by status

# %%
df_by_status = df_uncleared.groupby('STATUS')['SR_NUMBER'].agg('count').reset_index()
df_by_status
# Out:
#       STATUS  SR_NUMBER
# 0   Canceled        978
# 1  Completed      20041
# 2       Open         60
