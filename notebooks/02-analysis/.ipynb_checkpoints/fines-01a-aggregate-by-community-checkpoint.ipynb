# %% [markdown]
# # Summarize by Community
# last updated 3/3/24

# %% [markdown]
# <a name="read"></a>
# # 1. Read and Prepare Geocoded Fines and 311 Complaints Data

# %%
import pandas as pd

# %%
df_fines = pd.read_csv("../../data/05-finalized/dockets-summary.csv")
df_fines.head()
# Out:
#        docket     dept    violation_address         lat                long  \
# 0  19DS68300L  STRTSAN   4710 S WESTERN AVE   41.807859  -87.68479703503766
# 1  19DS69216L  STRTSAN     1425 W MORSE AVE  42.0074513         -87.6668285
# 2  19DS70010L  STRTSAN        715 E 47TH ST  41.8093383         -87.6080127
# 3  19DS72153L  STRTSAN  300 W WASHINGTON ST  41.8818694         -87.7401431
# 4  19DS72160L  STRTSAN   6929 N SHERIDAN RD  41.9598134          -87.654693
#
#             community ward_1523 violation_date  n_records
# 0       BRIGHTON PARK        15     2019-11-13          2
# 1         ROGERS PARK        49     2019-11-13          1
# 2     GRAND BOULEVARD         4     2019-11-13          1
# 3  WEST GARFIELD PARK        28     2019-11-12          5
# 4              UPTOWN        46     2019-11-14          1

# %%
df_311 = pd.read_csv("../../data/05-finalized/311-complaints-unshoveled.csv")
df_311['community_caps']=df_311['COMMUNITY_NAME'].str.upper()
df_311 = df_311.drop(columns=['COMMUNITY_NAME'])
df_311.head()
# Out:
#        SR_NUMBER SR_SHORT_CODE         CREATED_DATE          STREET_ADDRESS  \
# 0  SR20-05649092      SWSNOREM  2020-12-17 13:24:37   5200 S BLACKSTONE AVE
# 1  SR21-00001364      SWSNOREM  2021-01-01 11:40:33        66 E CHESTNUT ST
# 2  SR21-00000774      SWSNOREM  2021-01-01 09:11:15       2648 N WHIPPLE ST
# 3  SR20-05723378      SWSNOREM  2020-12-31 07:19:37  5015 N SPRINGFIELD AVE
# 4  SR21-00014080      SWSNOREM  2021-01-04 14:07:09         3757 N BELL AVE
#
#    COMMUNITY_AREA  WARD     STATUS         ORIGIN          CLOSED_DATE  \
# 0              41     4  Completed     Phone Call  2020-12-18 15:12:51
# 1               8    42  Completed  Mobile Device  2021-01-04 14:33:44
# 2              22    32  Completed       Internet  2021-01-06 13:37:58
# 3              14    39  Completed  Mobile Device  2021-01-08 15:30:57
# 4               5    47  Completed       Internet  2021-01-06 11:37:30
#
#     LATITUDE  LONGITUDE                              SR_TYPE  year  month  \
# 0  41.800909 -87.590515  Snow – Uncleared Sidewalk Complaint  2020     12
# 1  41.898399 -87.625723  Snow – Uncleared Sidewalk Complaint  2021      1
# 2  41.930233 -87.703706  Snow – Uncleared Sidewalk Complaint  2021      1
# 3  41.972439 -87.725430  Snow – Uncleared Sidewalk Complaint  2020     12
# 4  41.950316 -87.684472  Snow – Uncleared Sidewalk Complaint  2021      1
#
#          date     season  GEOID   community_caps
# 0  2020-12-17  2020-2021     41        HYDE PARK
# 1  2021-01-01  2020-2021      8  NEAR NORTH SIDE
# 2  2021-01-01  2020-2021     22     LOGAN SQUARE
# 3  2020-12-31  2020-2021     14      ALBANY PARK
# 4  2021-01-04  2020-2021      5     NORTH CENTER

# %% [markdown]
# ### census data

# %%
df_population = pd.read_csv("../../data/05-finalized/census-by-community.csv")
df_population.head()
# Out:
#    community_name  2020_pop       vac_hu        hu_tot      vacant   vacperc  \
# 0     Albany Park     48396  1448.000000  18230.000000    5.322983  0.004331
# 1  Archer Heights     14196   406.000000   4538.000000   29.231599  0.022770
# 2   Armour Square     13890   393.513552   5860.348806   15.696404  0.024625
# 3         Ashburn     41098   540.000000  13479.000000   59.468213  0.019123
# 4  Auburn Gresham     44878  3364.000000  20617.000000  119.122147  0.049388
#
#    community_caps
# 0     ALBANY PARK
# 1  ARCHER HEIGHTS
# 2   ARMOUR SQUARE
# 3         ASHBURN
# 4  AUBURN GRESHAM

# %%
len(df_population)
# Out:
# 77

# %% [markdown]
# <a name="community"></a>
# # Aggregate Dockets by Community
# Note that 7 communities have no dockets

# %%
df_comm_fines = df_fines.pivot_table(index='community',
                             columns='dept',
                             values='docket',
                             aggfunc=['count'],
                             fill_value=0).reset_index()
# Flatten the MultiIndex in columns
df_comm_fines.columns = ['_'.join(col).strip() for col in df_comm_fines.columns.values]

df_comm_fines = df_comm_fines.rename(columns={'community_':'community'})
df_comm_fines.rename(columns=lambda x: x.replace('count_','n_'), inplace=True)

# Reset the index to flatten it
df_comm_fines.reset_index(drop=True, inplace=True)

df_comm_fines['n_dockets'] = df_comm_fines.filter(like='n_').sum(axis=1)
df_comm_fines['community_caps']=df_comm_fines['community']
#df_comm_fines = df_comm_fines.drop(columns=['community'])

df_comm_fines.head()
# Out:
#         community  n_BAFCONP  n_POLICE  n_STRTSAN  n_TRANPORT  n_unknown  \
# 0     ALBANY PARK          0         0          0          15          0
# 1  ARCHER HEIGHTS          0         0          0          14          0
# 2   ARMOUR SQUARE          0         0          0          26          0
# 3         ASHBURN          0         0          0           2          0
# 4  AUBURN GRESHAM          0         0          3          16          0
#
#    n_dockets  community_caps
# 0         15     ALBANY PARK
# 1         14  ARCHER HEIGHTS
# 2         26   ARMOUR SQUARE
# 3          2         ASHBURN
# 4         19  AUBURN GRESHAM

# %%
# confirm totals
df_comm_fines['n_dockets'].sum()
# Out:
# 1918

# %%
len(df_comm_fines)
# Out:
# 72

# %% [markdown]
# # Aggregate 311 Complaints by Community

# %%
df_comm_311 = df_311.groupby('community_caps').size().reset_index(name='n_311_complaints')
df_comm_311['community_name']=df_comm_311['community_caps'].str.title()
df_comm_311 = df_comm_311.drop(columns=['community_name'])
df_comm_311.head()
# Out:
#    community_caps  n_311_complaints
# 0     ALBANY PARK               400
# 1  ARCHER HEIGHTS                60
# 2   ARMOUR SQUARE                77
# 3         ASHBURN               108
# 4  AUBURN GRESHAM               128

# %%
len(df_comm_311)
# Out:
# 77

# %%
df_comm_311['n_311_complaints'].sum()
# Out:
# 21079

# %% [markdown]
# # Merge Datasets

# %% [markdown]
# ### Merge Community Census Data with Dockets and 311 complaints

# %%
df_community = pd.merge(df_population,df_comm_fines, on = 'community_caps', how='left')
df_community = pd.merge(df_community,df_comm_311, on = 'community_caps')
df_community.fillna(0, inplace=True)
df_community['n_BAFCONP']=df_community['n_BAFCONP'].astype(int)
df_community['n_POLICE']=df_community['n_POLICE'].astype(int)
df_community['n_STRTSAN']=df_community['n_STRTSAN'].astype(int)
df_community['n_TRANPORT']=df_community['n_TRANPORT'].astype(int)
df_community.head()
# Out:
#    community_name  2020_pop       vac_hu        hu_tot      vacant   vacperc  \
# 0     Albany Park     48396  1448.000000  18230.000000    5.322983  0.004331
# 1  Archer Heights     14196   406.000000   4538.000000   29.231599  0.022770
# 2   Armour Square     13890   393.513552   5860.348806   15.696404  0.024625
# 3         Ashburn     41098   540.000000  13479.000000   59.468213  0.019123
# 4  Auburn Gresham     44878  3364.000000  20617.000000  119.122147  0.049388
#
#    community_caps       community  n_BAFCONP  n_POLICE  n_STRTSAN  n_TRANPORT  \
# 0     ALBANY PARK     ALBANY PARK          0         0          0          15
# 1  ARCHER HEIGHTS  ARCHER HEIGHTS          0         0          0          14
# 2   ARMOUR SQUARE   ARMOUR SQUARE          0         0          0          26
# 3         ASHBURN         ASHBURN          0         0          0           2
# 4  AUBURN GRESHAM  AUBURN GRESHAM          0         0          3          16
#
#    n_unknown  n_dockets  n_311_complaints
# 0        0.0       15.0               400
# 1        0.0       14.0                60
# 2        0.0       26.0                77
# 3        0.0        2.0               108
# 4        0.0       19.0               128

# %%
# confirm I have 77 communities
len(df_community)
# Out:
# 77

# %%
df_community[df_community['community_name']=='Loop']
# Out:
#    community_name  2020_pop  vac_hu   hu_tot    vacant   vacperc  \
# 65           Loop     42298  3598.0  24565.0  30.45673  0.028743
#
#    community_caps community  n_BAFCONP  n_POLICE  n_STRTSAN  n_TRANPORT  \
# 65           LOOP      LOOP          0         0          2          29
#
#     n_unknown  n_dockets  n_311_complaints
# 65        0.0       31.0               177

# %% [markdown]
# # Calculations

# %%
df_community['dp10k'] = \
(10000/4)*df_community['n_dockets']/df_community['2020_pop']

df_community['streets_p10k'] = \
(10000/4)*df_community['n_STRTSAN']/df_community['2020_pop']

df_community['cdot_p10k'] = \
(10000/4)*df_community['n_TRANPORT']/df_community['2020_pop']

df_community['police_p10k'] = \
(10000/4)*df_community['n_POLICE']/df_community['2020_pop']

df_community['n_p10k'] = \
(10000/4)*df_community['n_BAFCONP']/df_community['2020_pop']

df_community['311_p10k'] = \
(10000/4)*df_community['n_311_complaints']/df_community['2020_pop']

df_community['complaint_ratio'] = df_community['n_TRANPORT']/df_community['n_311_complaints']

# %%
df_community
# Out:
#     community_name  2020_pop       vac_hu        hu_tot      vacant   vacperc  \
# 0      Albany Park     48396  1448.000000  18230.000000    5.322983  0.004331
# 1   Archer Heights     14196   406.000000   4538.000000   29.231599  0.022770
# 2    Armour Square     13890   393.513552   5860.348806   15.696404  0.024625
# 3          Ashburn     41098   540.000000  13479.000000   59.468213  0.019123
# 4   Auburn Gresham     44878  3364.000000  20617.000000  119.122147  0.049388
# ..             ...       ...          ...           ...         ...       ...
# 72       West Lawn     33662   525.000000   9701.000000   46.394184  0.024551
# 73    West Pullman     26104  2147.000000  11210.000000  221.071452  0.096914
# 74      West Ridge     77122  2185.000000  28054.000000   11.765845  0.005207
# 75       West Town     87781  3177.000000  41891.000000   62.407906  0.021311
# 76        Woodlawn     24425  2436.000000  11960.000000  122.772101  0.092636
#
#     community_caps       community  n_BAFCONP  n_POLICE  ...  n_unknown  \
# 0      ALBANY PARK     ALBANY PARK          0         0  ...        0.0
# 1   ARCHER HEIGHTS  ARCHER HEIGHTS          0         0  ...        0.0
# 2    ARMOUR SQUARE   ARMOUR SQUARE          0         0  ...        0.0
# 3          ASHBURN         ASHBURN          0         0  ...        0.0
# 4   AUBURN GRESHAM  AUBURN GRESHAM          0         0  ...        0.0
# ..             ...             ...        ...       ...  ...        ...
# 72       WEST LAWN       WEST LAWN          0         0  ...        0.0
# 73    WEST PULLMAN    WEST PULLMAN          0         1  ...        0.0
# 74      WEST RIDGE      WEST RIDGE          0         0  ...        0.0
# 75       WEST TOWN       WEST TOWN          0         0  ...        0.0
# 76        WOODLAWN        WOODLAWN          2         2  ...        0.0
#
#     n_dockets  n_311_complaints     dp10k  streets_p10k  cdot_p10k  \
# 0        15.0               400  0.774857      0.000000   0.774857
# 1        14.0                60  2.465483      0.000000   2.465483
# 2        26.0                77  4.679626      0.000000   4.679626
# 3         2.0               108  0.121660      0.000000   0.121660
# 4        19.0               128  1.058425      0.167120   0.891305
# ..        ...               ...       ...           ...        ...
# 72       17.0               146  1.262551      0.148535   1.114016
# 73        5.0                23  0.478854      0.095771   0.287312
# 74       24.0               804  0.777988      0.226913   0.551075
# 75       97.0              1609  2.762557      0.028480   2.734077
# 76        4.0               120  0.409417      0.000000   0.000000
#
#     police_p10k    n_p10k   311_p10k  complaint_ratio
# 0      0.000000  0.000000  20.662865         0.037500
# 1      0.000000  0.000000  10.566357         0.233333
# 2      0.000000  0.000000  13.858891         0.337662
# 3      0.000000  0.000000   6.569663         0.018519
# 4      0.000000  0.000000   7.130443         0.125000
# ..          ...       ...        ...              ...
# 72     0.000000  0.000000  10.843087         0.102740
# 73     0.095771  0.000000   2.202728         0.130435
# 74     0.000000  0.000000  26.062602         0.021144
# 75     0.000000  0.000000  45.824267         0.059664
# 76     0.204708  0.204708  12.282497         0.000000
#
# [77 rows x 22 columns]

# %% [markdown]
# ### verify totals
# compare these totals with ward-level summaries
#
# * n_BAFCONP                                                         2
# * n_POLICE                                                         25
# * n_STRTSAN                                                       495
# * n_TRANPORT                                                     1359
# * n_dockets                                                      1881
# * n_311_complaints                                                21079

# %%
df_community['n_BAFCONP'].sum()
# Out:
# 2

# %%
df_community['n_POLICE'].sum()
# Out:
# 25

# %%
df_community['n_STRTSAN'].sum()
# Out:
# 497

# %%
df_community['n_TRANPORT'].sum()
# Out:
# 1388

# %%
df_community['n_dockets'].sum()
# Out:
# 1913.0

# %%
df_community['n_311_complaints'].sum()
# Out:
# 21079

# %% [markdown]
# # Export

# %%
df_community.to_csv("../../results/ssw02-fines/community-summary.csv", index= False)
