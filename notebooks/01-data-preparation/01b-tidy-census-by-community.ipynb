# %%
import pandas as pd

# %%
df_census = pd.read_csv("../../data/01-raw/population_cmap_2022.csv")

# %%
df_census
# Out:
#     OBJECTID  GEOID            GEOG  2000_POP  2010_POP  2020_POP  2020_HH  \
# 0          1     14     Albany Park     57655     51542     48396    17161
# 1          2     57  Archer Heights     12644     13393     14196     4163
# 2          3     34   Armour Square     12032     13391     13890     5648
# 3          4     70         Ashburn     39584     41081     41098    12909
# 4          5     71  Auburn Gresham     55928     48743     44878    18071
# ..       ...    ...             ...       ...       ...       ...      ...
# 72        73     65       West Lawn     29235     33355     33662     9244
# 73        74     53    West Pullman     36649     29651     26104     9650
# 74        75      2      West Ridge     73199     71942     77122    26493
# 75        76     24       West Town     87435     82236     87781    42920
# 76        77     42        Woodlawn     27086     23740     24425    10517
#
# ...

# %%
df_census.dtypes
# Out:
# OBJECTID                            int64
# GEOID                               int64
# GEOG                               object
# 2000_POP                            int64
# 2010_POP                            int64
#                                    ...
# pct_pop_access_10_acres_per_1k    float64
# impervious_acres_per_hh           float64
# modhigh_ta_pop_pct                float64
# modhigh_ta_emp_pct                float64
# nonsov_pct                        float64
# Length: 259, dtype: object

# %% [markdown]
# ### Replace 'The Loop' with 'Loop', to match community names in other data sets

# %%
df_census['GEOG']= df_census['GEOG'].replace('The Loop','Loop')
df_census
# Out:
#     OBJECTID  GEOID            GEOG  2000_POP  2010_POP  2020_POP  2020_HH  \
# 0          1     14     Albany Park     57655     51542     48396    17161
# 1          2     57  Archer Heights     12644     13393     14196     4163
# 2          3     34   Armour Square     12032     13391     13890     5648
# 3          4     70         Ashburn     39584     41081     41098    12909
# 4          5     71  Auburn Gresham     55928     48743     44878    18071
# ..       ...    ...             ...       ...       ...       ...      ...
# 72        73     65       West Lawn     29235     33355     33662     9244
# 73        74     53    West Pullman     36649     29651     26104     9650
# 74        75      2      West Ridge     73199     71942     77122    26493
# 75        76     24       West Town     87435     82236     87781    42920
# 76        77     42        Woodlawn     27086     23740     24425    10517
#
# ...

# %% [markdown]
# # Export

# %%
df_census.to_csv("../../data/02-tidied/census-by-community.csv")
