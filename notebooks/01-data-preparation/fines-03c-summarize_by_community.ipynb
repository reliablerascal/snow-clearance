# %% [markdown]
# <h1>Snow Clearance Fines, 2019-2023</h1>
# 15 February 2024
#
# This analysis looks at fines levied for uncleared sidewalks, based on FOIA data requested from the Department of Administrative Hearings (H064920-011124.xlsx). This dataset contained 3058 records dating from 1/1/2001 to 9/12/2023; filtered for those between 7/1/2019 and 6/30/2023 has 2560 records. Four of these could not be geocoded due to "unknown" address.<br>
# <br>
# <ol>
# <li><a href="#read">Read Data</a>
#              <li><a href="#community">Summarize Dockets by Community</a>- look for patterns across Chicago community areas
# </ol>

# %% [markdown]
# ### Record Count
# <ul>
#     <li>2556 valid fines records from July 1 2019 to June 30 2023
#         <li>1912 dockets. Some dockets contain multiple fines records, which are identical except for a different fine amount in each record.
#             <li>1735 addresses. some addresses have been fined by both CDOT and Streets & Sanitation, with a separate court docket for each.
#                 <li>some addresses have been fined by multiple agencies
#     </ul>

# %% [markdown]
# ### Preliminary Findings
# <ul>
#     <li>73% of court dockets were issued by CDOT, 26% by Streets and Sanitation. The remaining 1% were issued by the police or Business Affairs and Consumer Protection
#     <li>Englewood, Garfield Ridge, and West Englewood are the three communities with the highest number of dockets per capita
#     <li>Only 25 court dockets were issued by police. West Englewood, Englewood, and Garfield Ridge have the highest rates and account for half the dockets citywide.
#         <li>For dockets issued by CDOT, Garfield Ridge, Grand Boulevard, and Armour Square have the highest per capita rate
#             <li>For dockets issued by Streets and Sanitation, Englewood, West Englewood, and Brighton Park have the highest per capita rate
#     </ul>

# %% [markdown]
# <a name="read"></a>
# # 1. Read and Prepare Geocoded Fines Data

# %%
import pandas as pd

# %% [markdown]
# Note the following data preparation steps prior to this notebook
# <ol>
# <li>Prepared data by parsing dates and correcting data entry errors in addresses; see <a href="fines-01-prep-data.ipynb">fines-01-prep-data.ipynb</a>.
#     <li>Geocoded addresses to identify lat and long coordinates, and spatially joined addresses to Community Areas shapefile. I did this offline in QGIS.
#         </ol>

# %%
df_dockets = pd.read_csv("../../data/05-standardized/fines-by-docket.csv")
df_dockets.head()
# Out:
#        docket     dept              address        lat       long  \
# 0  19DS68300L  STRTSAN   4710 S WESTERN AVE  41.807859 -87.684797
# 1  19DS69216L  STRTSAN     1425 W MORSE AVE  42.007451 -87.666828
# 2  19DS70010L  STRTSAN        715 E 47TH ST  41.809338 -87.608013
# 3  19DS72153L  STRTSAN  300 W WASHINGTON ST  41.882868 -88.210529
# 4  19DS72160L  STRTSAN   6929 N SHERIDAN RD  41.959813 -87.654693
#
#          community violation_date     season  n_records  total_fine
# 0    BRIGHTON PARK     2019/11/13  2019-2020          1       150.0
# 1      ROGERS PARK     2019/11/13  2019-2020          1        50.0
# 2  GRAND BOULEVARD     2019/11/13  2019-2020          1       150.0
# 3             LOOP     2019/11/12  2019-2020          3       650.0
# 4           UPTOWN     2019/11/14  2019-2020          1       500.0

# %%
len(df_dockets)
# Out:
# 1912

# %% [markdown]
# <a name="community"></a>
# # Create Community-Level Dataframe
# Note that 7 communities have no dockets

# %%
df_community = df_dockets.pivot_table(index='community',
                             columns='dept',
                             values='total_fine',
                             aggfunc=['count'],
                             fill_value=0).reset_index()
# Flatten the MultiIndex in columns
df_community.columns = ['_'.join(col).strip() for col in df_community.columns.values]

df_community = df_community.rename(columns={'community_':'community'})

# Reset the index to flatten it
df_community.reset_index(drop=True, inplace=True)

df_community['n_dockets']=df_community['count_BAFCONP']+df_community['count_POLICE']+df_community['count_STRTSAN']+df_community['count_TRANPORT']

df_community.head()
# Out:
#         community  count_BAFCONP  count_POLICE  count_STRTSAN  count_TRANPORT  \
# 0     ALBANY PARK              0             0              0              15
# 1  ARCHER HEIGHTS              0             0              0              12
# 2   ARMOUR SQUARE              0             0              0              26
# 3         ASHBURN              0             0              0               2
# 4  AUBURN GRESHAM              0             0              3              16
#
#    n_dockets
# 0         15
# 1         12
# 2         26
# 3          2
# 4         19

# %%
df_community[df_community['community']=='LOOP']
# Out:
#    community  count_BAFCONP  count_POLICE  count_STRTSAN  count_TRANPORT  \
# 38      LOOP              0             0              3              21
#
#     n_dockets
# 38         24

# %% [markdown]
# # Merge Community-Level Datasets

# %% [markdown]
# ### read community population

# %%
# retrieved on 1/11/24, but 2020 Census Population figures should be static
df_population = pd.read_csv("../../data/02-tidied/census-by-community.csv")

# simplify dataframe to get only essentials
df_population = df_population[['GEOID','GEOG','2020_POP']]
df_population = df_population.rename(columns={'GEOG':'COMMUNITY_NAME'})
df_population['COMMUNITY_CAPS']=df_population['COMMUNITY_NAME'].str.upper()
df_population.head()
# Out:
#    GEOID  COMMUNITY_NAME  2020_POP  COMMUNITY_CAPS
# 0     14     Albany Park     48396     ALBANY PARK
# 1     57  Archer Heights     14196  ARCHER HEIGHTS
# 2     34   Armour Square     13890   ARMOUR SQUARE
# 3     70         Ashburn     41098         ASHBURN
# 4     71  Auburn Gresham     44878  AUBURN GRESHAM

# %% [markdown]
# ### merge in community population data

# %%
df_community_summary = pd.merge(df_community,df_population,left_on='community',right_on='COMMUNITY_CAPS',how='right')
df_community_summary.head()
# Out:
#         community  count_BAFCONP  count_POLICE  count_STRTSAN  count_TRANPORT  \
# 0     ALBANY PARK            0.0           0.0            0.0            15.0
# 1  ARCHER HEIGHTS            0.0           0.0            0.0            12.0
# 2   ARMOUR SQUARE            0.0           0.0            0.0            26.0
# 3         ASHBURN            0.0           0.0            0.0             2.0
# 4  AUBURN GRESHAM            0.0           0.0            3.0            16.0
#
#    n_dockets  GEOID  COMMUNITY_NAME  2020_POP  COMMUNITY_CAPS
# 0       15.0     14     Albany Park     48396     ALBANY PARK
# 1       12.0     57  Archer Heights     14196  ARCHER HEIGHTS
# 2       26.0     34   Armour Square     13890   ARMOUR SQUARE
# 3        2.0     70         Ashburn     41098         ASHBURN
# 4       19.0     71  Auburn Gresham     44878  AUBURN GRESHAM

# %% [markdown]
# ### calculate dockets per capita

# %%
# per 10,000 capita, per year over 4 years
df_community_summary['dp10k'] = \
(10000/4)*df_community_summary['n_dockets']/df_community_summary['2020_POP']
df_community_summary['streets_p10k'] = \
(10000/4)*df_community_summary['count_STRTSAN']/df_community_summary['2020_POP']
df_community_summary['cdot_p10k'] = \
(10000/4)*df_community_summary['count_TRANPORT']/df_community_summary['2020_POP']
df_community_summary['police_p10k'] = \
(10000/4)*df_community_summary['count_POLICE']/df_community_summary['2020_POP']
df_community_summary['business_p10k'] = \
(10000/4)*df_community_summary['count_BAFCONP']/df_community_summary['2020_POP']

# %% [markdown]
# ### merge 311 unshoveled sidewalk complaints

# %%
df_311_unshoveled = pd.read_csv("../../results/311-uncleared-by-community.csv")

# %%
df_311_unshoveled.head()
# Out:
#    COMMUNITY_NAME  Sidewalks Per 10k  Snow – Uncleared Sidewalk Complaint  \
# 0  Lincoln Square          57.354176                                  929
# 1    Logan Square          55.361753                                 1587
# 2          Uptown          46.124655                                 1055
# 3       West Town          45.824267                                 1609
# 4    Lincoln Park          42.628951                                 1202
#
#    2020_POP  COMMUNITY_CAPS
# 0     40494  LINCOLN SQUARE
# 1     71665    LOGAN SQUARE
# 2     57182          UPTOWN
# 3     87781       WEST TOWN
# 4     70492    LINCOLN PARK

# %%
# take only the fields I need
merge_cols = ['COMMUNITY_NAME','Sidewalks Per 10k','Snow – Uncleared Sidewalk Complaint']

# %%
df_community_summary = pd.merge(df_community_summary,df_311_unshoveled[merge_cols],on="COMMUNITY_NAME")
df_community_summary = df_community_summary.rename(columns={'Snow – Uncleared Sidewalk Complaint':'snow_complaints'})
df_community_summary.head()
# Out:
#         community  count_BAFCONP  count_POLICE  count_STRTSAN  count_TRANPORT  \
# 0     ALBANY PARK            0.0           0.0            0.0            15.0
# 1  ARCHER HEIGHTS            0.0           0.0            0.0            12.0
# 2   ARMOUR SQUARE            0.0           0.0            0.0            26.0
# 3         ASHBURN            0.0           0.0            0.0             2.0
# 4  AUBURN GRESHAM            0.0           0.0            3.0            16.0
#
#    n_dockets  GEOID  COMMUNITY_NAME  2020_POP  COMMUNITY_CAPS     dp10k  \
# 0       15.0     14     Albany Park     48396     ALBANY PARK  0.774857
# 1       12.0     57  Archer Heights     14196  ARCHER HEIGHTS  2.113271
# 2       26.0     34   Armour Square     13890   ARMOUR SQUARE  4.679626
# 3        2.0     70         Ashburn     41098         ASHBURN  0.121660
# 4       19.0     71  Auburn Gresham     44878  AUBURN GRESHAM  1.058425
#
#    streets_p10k  cdot_p10k  police_p10k  business_p10k  Sidewalks Per 10k_x  \
# 0       0.00000   0.774857          0.0            0.0            20.662865
# 1       0.00000   2.113271          0.0            0.0            10.566357
# 2       0.00000   4.679626          0.0            0.0            13.858891
# 3       0.00000   0.121660          0.0            0.0             6.569663
# 4       0.16712   0.891305          0.0            0.0             7.130443
#
#    snow_complaints  citation_rate  Sidewalks Per 10k_y  snow_complaints
# 0              400       0.037500            20.662865              400
# 1               60       0.200000            10.566357               60
# 2               77       0.337662            13.858891               77
# 3              108       0.018519             6.569663              108
# 4              128       0.125000             7.130443              128

# %%
df_community_summary['citation_rate'] = df_community_summary['count_TRANPORT']/df_community_summary['snow_complaints']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1003/7163453.py in <module>
# ----> 1 df_community_summary['citation_rate'] = df_community_summary['count_TRANPORT']/df_community_summary['snow_complaints']
#
# ~/.local/lib/python3.10/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# ~/.local/lib/python3.10/site-packages/pandas/core/arraylike.py in __rtruediv__(self, other)
#     212     @unpack_zerodim_and_defer("__rtruediv__")
#     213     def __rtruediv__(self, other):
# --> 214         return self._arith_method(other, roperator.rtruediv)
#     215
#     216     @unpack_zerodim_and_defer("__floordiv__")
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in _arith_method(self, other, op)
#    7892         other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
#    7893
# -> 7894         self, other = self._align_for_op(other, axis, flex=True, level=None)
#    7895
#    7896         with np.errstate(all="ignore"):
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in _align_for_op(self, other, axis, flex, level)
#    8193                     )
#    8194
# -> 8195             left, right = left.align(
#    8196                 right,
#    8197                 join="outer",
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#   10439
#   10440         elif isinstance(other, ABCSeries):
# > 10441             left, _right, join_index = self._align_series(
#   10442                 other,
#   10443                 join=join,
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in _align_series(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis)
#   10582             if lidx is not None:
#   10583                 bm_axis = self._get_block_manager_axis(1)
# > 10584                 fdata = fdata.reindex_indexer(join_index, lidx, axis=bm_axis)
#   10585
#   10586             if copy and fdata is self._mgr:
#
# ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     673         # some axes don't allow reindexing with dups
#     674         if not allow_dups:
# --> 675             self.axes[axis]._validate_can_reindex(indexer)
#     676
#     677         if axis >= self.ndim:
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in _validate_can_reindex(self, indexer)
#    4316         # trying to reindex on an axis with duplicates
#    4317         if not self._index_as_unique and len(indexer):
# -> 4318             raise ValueError("cannot reindex on an axis with duplicate labels")
#    4319
#    4320     def reindex(
#
# ValueError: cannot reindex on an axis with duplicate labels

# %% [markdown]
# # Summarize

# %% [markdown]
# ### top communities for dockets per capita

# %%
df_community_summary.sort_values(by='dp10k',ascending = False).head()
# Out:
#           community  count_BAFCONP  count_POLICE  count_STRTSAN  \
# 23        ENGLEWOOD            0.0           4.0           58.0
# 27   GARFIELD RIDGE            0.0           3.0            2.0
# 69   WEST ENGLEWOOD            0.0           6.0           60.0
# 28  GRAND BOULEVARD            0.0           0.0            5.0
# 54          OAKLAND            0.0           0.0            1.0
#
#     count_TRANPORT  n_dockets  GEOID   COMMUNITY_NAME  2020_POP  \
# 23             7.0       69.0     68        Englewood     24369
# 27            86.0       91.0     56   Garfield Ridge     35439
# 69             9.0       75.0     67   West Englewood     29647
# 28            47.0       52.0     38  Grand Boulevard     24589
# 54            12.0       13.0     36          Oakland      6799
#
#      COMMUNITY_CAPS     dp10k  streets_p10k  cdot_p10k  police_p10k  \
# 23        ENGLEWOOD  7.078666      5.950183   0.718125     0.410357
# 27   GARFIELD RIDGE  6.419481      0.141088   6.066763     0.211631
# 69   WEST ENGLEWOOD  6.324417      5.059534   0.758930     0.505953
# 28  GRAND BOULEVARD  5.286917      0.508357   4.778560     0.000000
# 54          OAKLAND  4.780115      0.367701   4.412414     0.000000
#
#     business_p10k  Sidewalks Per 10k_x  snow_complaints  citation_rate  \
# 23            0.0             9.540810               93       0.075269
# 27            0.0            11.428088              162       0.530864
# 69            0.0             5.059534               60       0.150000
# 28            0.0            21.351011              210       0.223810
# 54            0.0            15.443448               42       0.285714
#
#     Sidewalks Per 10k_y  snow_complaints
# 23             9.540810               93
# 27            11.428088              162
# 69             5.059534               60
# 28            21.351011              210
# 54            15.443448               42

# %% [markdown]
# ### top communities for Streets and Sanitation dockets per capita

# %%
df_community_summary.sort_values(by='streets_p10k',ascending = False).head(10)
# Out:
#                  community  count_BAFCONP  count_POLICE  count_STRTSAN  \
# 23               ENGLEWOOD            0.0           4.0           58.0
# 69          WEST ENGLEWOOD            0.0           6.0           60.0
# 11           BRIGHTON PARK            0.0           0.0           70.0
# 49                NEW CITY            0.0           0.0           62.0
# 29  GREATER GRAND CROSSING            0.0           1.0           34.0
# 36                 KENWOOD            0.0           0.0           15.0
# 59             ROGERS PARK            0.0           0.0           32.0
# 19      EAST GARFIELD PARK            0.0           0.0            9.0
# 41         LOWER WEST SIDE            0.0           0.0           15.0
# 39          LINCOLN SQUARE            0.0           0.0           13.0
#
#     count_TRANPORT  n_dockets  GEOID          COMMUNITY_NAME  2020_POP  \
# 23             7.0       69.0     68               Englewood     24369
# 69             9.0       75.0     67          West Englewood     29647
# 11            11.0       81.0     58           Brighton Park     45053
# 49             7.0       69.0     61                New City     43628
# 29             1.0       36.0     69  Greater Grand Crossing     31471
# 36            18.0       33.0     39                 Kenwood     19116
# 59             7.0       39.0      1             Rogers Park     55628
# 19            29.0       38.0     27      East Garfield Park     19992
# 41            23.0       38.0     31         Lower West Side     33751
# 39            24.0       37.0      4          Lincoln Square     40494
#
#             COMMUNITY_CAPS     dp10k  streets_p10k  cdot_p10k  police_p10k  \
# 23               ENGLEWOOD  7.078666      5.950183   0.718125     0.410357
# 69          WEST ENGLEWOOD  6.324417      5.059534   0.758930     0.505953
# 11           BRIGHTON PARK  4.494706      3.884314   0.610392     0.000000
# 49                NEW CITY  3.953883      3.552764   0.401119     0.000000
# 29  GREATER GRAND CROSSING  2.859776      2.700899   0.079438     0.079438
# 36                 KENWOOD  4.315756      1.961707   2.354049     0.000000
# 59             ROGERS PARK  1.752714      1.438125   0.314590     0.000000
# 19      EAST GARFIELD PARK  4.751901      1.125450   3.626451     0.000000
# 41         LOWER WEST SIDE  2.814731      1.111078   1.703653     0.000000
# 39          LINCOLN SQUARE  2.284289      0.802588   1.481701     0.000000
#
#     business_p10k  Sidewalks Per 10k_x  snow_complaints  citation_rate  \
# 23            0.0             9.540810               93       0.075269
# 69            0.0             5.059534               60       0.150000
# 11            0.0             6.880785              124       0.088710
# 49            0.0             7.048226              123       0.056911
# 29            0.0            10.565282              133       0.007519
# 36            0.0            15.955221              122       0.147541
# 59            0.0            22.965054              511       0.013699
# 19            0.0            18.882553              151       0.192053
# 41            0.0            24.073361              325       0.070769
# 39            0.0            57.354176              929       0.025834
#
#     Sidewalks Per 10k_y  snow_complaints
# 23             9.540810               93
# 69             5.059534               60
# 11             6.880785              124
# 49             7.048226              123
# 29            10.565282              133
# 36            15.955221              122
# 59            22.965054              511
# 19            18.882553              151
# 41            24.073361              325
# 39            57.354176              929

# %% [markdown]
# ### top communities for CDOT dockets per capita

# %%
df_top = df_community_summary.sort_values(by='cdot_p10k',ascending = False).head(10)
df_top = df_top[['COMMUNITY_NAME','count_TRANPORT','snow_complaints','cdot_p10k']]
df_top
# Out:
#         COMMUNITY_NAME  count_TRANPORT  snow_complaints  snow_complaints  \
# 27      Garfield Ridge            86.0              162              162
# 28     Grand Boulevard            47.0              210              210
# 2        Armour Square            26.0               77               77
# 38        Lincoln Park           126.0             1202             1202
# 54             Oakland            12.0               42               42
# 10          Bridgeport            53.0              307              307
# 19  East Garfield Park            29.0              151              151
# 47     Near South Side            41.0              174              174
# 43           Montclare            19.0               81               81
# 48      Near West Side            83.0              590              590
#
#     cdot_p10k
# 27   6.066763
# 28   4.778560
# 2    4.679626
# 38   4.468592
# 54   4.412414
# 10   3.931517
# 19   3.626451
# 47   3.559646
# 43   3.298382
# 48   3.056820

# %%
#calculate citywide average dockets per capita
(10000/4)*df_community_summary['count_TRANPORT'].sum()/df_community_summary['2020_POP'].sum()
# Out:
# 1.2638262779715173

# %% [markdown]
# ### top communities for CDOT dockets per complaint

# %%
df_per_complaint = df_community_summary.sort_values(by='citation_rate',ascending = False)
df_per_complaint = df_per_complaint.dropna()
df_top_communities = df_per_complaint[['COMMUNITY_NAME','count_TRANPORT','snow_complaints','citation_rate']].head()
df_top_communities
# Out:
#      COMMUNITY_NAME  count_TRANPORT  snow_complaints  snow_complaints  \
# 27   Garfield Ridge            86.0              162              162
# 16         Clearing            22.0               54               54
# 2     Armour Square            26.0               77               77
# 54          Oakland            12.0               42               42
# 47  Near South Side            41.0              174              174
#
#     citation_rate
# 27       0.530864
# 16       0.407407
# 2        0.337662
# 54       0.285714
# 47       0.235632

# %%
df_bottom_communities = df_per_complaint[['COMMUNITY_NAME','count_TRANPORT','snow_complaints','citation_rate']].tail(20)
df_bottom_communities
# Out:
#             COMMUNITY_NAME  count_TRANPORT  snow_complaints  snow_complaints  \
# 24             Forest Glen             5.0              172              172
# 53            Norwood Park             5.0              175              175
# 18                 Dunning             5.0              183              183
# 33               Hyde Park             5.0              192              192
# 39          Lincoln Square            24.0              929              929
# 7                 Avondale            13.0              509              509
# 56            Portage Park            14.0              551              551
# 37               Lake View            42.0             1665             1665
# 34             Irving Park            16.0              752              752
# 73              West Ridge            17.0              804              804
# 9                  Beverly             2.0              107              107
# 35          Jefferson Park             3.0              161              161
# 3                  Ashburn             2.0              108              108
# 44             Morgan Park             1.0               55               55
# 59             Rogers Park             7.0              511              511
# 65                  Uptown             9.0             1055             1055
# 29  Greater Grand Crossing             1.0              133              133
# 21               Edgewater             2.0              597              597
# 58               Riverdale             0.0                7                7
# 75                Woodlawn             0.0              120              120
#
#     citation_rate
# 24       0.029070
# 53       0.028571
# 18       0.027322
# 33       0.026042
# 39       0.025834
# 7        0.025540
# 56       0.025408
# 37       0.025225
# 34       0.021277
# 73       0.021144
# 9        0.018692
# 35       0.018634
# 3        0.018519
# 44       0.018182
# 59       0.013699
# 65       0.008531
# 29       0.007519
# 21       0.003350
# 58       0.000000
# 75       0.000000

# %%
df_community_summary['count_TRANPORT'].sum()/df_community_summary['snow_complaints'].sum()
# Out:
# snow_complaints    0.0654
# snow_complaints    0.0654
# dtype: float64

# %% [markdown]
# ### top communities for police dockets per capita

# %%
df_community_summary.sort_values(by='police_p10k',ascending = False).head()
# Out:
#          community  count_BAFCONP  count_POLICE  count_STRTSAN  \
# 69  WEST ENGLEWOOD            0.0           6.0           60.0
# 23       ENGLEWOOD            0.0           4.0           58.0
# 27  GARFIELD RIDGE            0.0           3.0            2.0
# 75        WOODLAWN            2.0           2.0            0.0
# 8   BELMONT CRAGIN            0.0           5.0            8.0
#
#     count_TRANPORT  n_dockets  GEOID  COMMUNITY_NAME  2020_POP  \
# 69             9.0       75.0     67  West Englewood     29647
# 23             7.0       69.0     68       Englewood     24369
# 27            86.0       91.0     56  Garfield Ridge     35439
# 75             0.0        4.0     42        Woodlawn     24425
# 8             54.0       67.0     19  Belmont Cragin     78116
#
#     COMMUNITY_CAPS     dp10k  streets_p10k  cdot_p10k  police_p10k  \
# 69  WEST ENGLEWOOD  6.324417      5.059534   0.758930     0.505953
# 23       ENGLEWOOD  7.078666      5.950183   0.718125     0.410357
# 27  GARFIELD RIDGE  6.419481      0.141088   6.066763     0.211631
# 75        WOODLAWN  0.409417      0.000000   0.000000     0.204708
# 8   BELMONT CRAGIN  2.144247      0.256029   1.728199     0.160018
#
#     business_p10k  Sidewalks Per 10k_x  snow_complaints  citation_rate  \
# 69       0.000000             5.059534               60       0.150000
# 23       0.000000             9.540810               93       0.075269
# 27       0.000000            11.428088              162       0.530864
# 75       0.204708            12.282497              120       0.000000
# 8        0.000000             8.929029              279       0.193548
#
#     Sidewalks Per 10k_y  snow_complaints
# 69             5.059534               60
# 23             9.540810               93
# 27            11.428088              162
# 75            12.282497              120
# 8              8.929029              279

# %%
# number of police dockets by community, since there's a small number
df_community_summary.sort_values(by='count_POLICE',ascending = False).head()
# Out:
#          community  count_BAFCONP  count_POLICE  count_STRTSAN  \
# 69  WEST ENGLEWOOD            0.0           6.0           60.0
# 8   BELMONT CRAGIN            0.0           5.0            8.0
# 23       ENGLEWOOD            0.0           4.0           58.0
# 27  GARFIELD RIDGE            0.0           3.0            2.0
# 75        WOODLAWN            2.0           2.0            0.0
#
#     count_TRANPORT  n_dockets  GEOID  COMMUNITY_NAME  2020_POP  \
# 69             9.0       75.0     67  West Englewood     29647
# 8             54.0       67.0     19  Belmont Cragin     78116
# 23             7.0       69.0     68       Englewood     24369
# 27            86.0       91.0     56  Garfield Ridge     35439
# 75             0.0        4.0     42        Woodlawn     24425
#
#     COMMUNITY_CAPS     dp10k  streets_p10k  cdot_p10k  police_p10k  \
# 69  WEST ENGLEWOOD  6.324417      5.059534   0.758930     0.505953
# 8   BELMONT CRAGIN  2.144247      0.256029   1.728199     0.160018
# 23       ENGLEWOOD  7.078666      5.950183   0.718125     0.410357
# 27  GARFIELD RIDGE  6.419481      0.141088   6.066763     0.211631
# 75        WOODLAWN  0.409417      0.000000   0.000000     0.204708
#
#     business_p10k  Sidewalks Per 10k_x  snow_complaints  citation_rate  \
# 69       0.000000             5.059534               60       0.150000
# 8        0.000000             8.929029              279       0.193548
# 23       0.000000             9.540810               93       0.075269
# 27       0.000000            11.428088              162       0.530864
# 75       0.204708            12.282497              120       0.000000
#
#     Sidewalks Per 10k_y  snow_complaints
# 69             5.059534               60
# 8              8.929029              279
# 23             9.540810               93
# 27            11.428088              162
# 75            12.282497              120

# %% [markdown]
# ### top communities for business affairs dockets per capita

# %%
df_community_summary.sort_values(by='business_p10k',ascending = False).head()
# Out:
#          community  count_BAFCONP  count_POLICE  count_STRTSAN  \
# 75        WOODLAWN            2.0           2.0            0.0
# 48  NEAR WEST SIDE            0.0           0.0            3.0
# 54         OAKLAND            0.0           0.0            1.0
# 53    NORWOOD PARK            0.0           0.0            1.0
# 52      NORTH PARK            0.0           0.0            1.0
#
#     count_TRANPORT  n_dockets  GEOID  COMMUNITY_NAME  2020_POP  \
# 75             0.0        4.0     42        Woodlawn     24425
# 48            83.0       86.0     28  Near West Side     67881
# 54            12.0       13.0     36         Oakland      6799
# 53             5.0        6.0     10    Norwood Park     38303
# 52             9.0       10.0     13      North Park     17559
#
#     COMMUNITY_CAPS     dp10k  streets_p10k  cdot_p10k  police_p10k  \
# 75        WOODLAWN  0.409417      0.000000   0.000000     0.204708
# 48  NEAR WEST SIDE  3.167307      0.110487   3.056820     0.000000
# 54         OAKLAND  4.780115      0.367701   4.412414     0.000000
# 53    NORWOOD PARK  0.391614      0.065269   0.326345     0.000000
# 52      NORTH PARK  1.423771      0.142377   1.281394     0.000000
#
#     business_p10k  Sidewalks Per 10k_x  snow_complaints  citation_rate  \
# 75       0.204708            12.282497              120       0.000000
# 48       0.000000            21.729203              590       0.140678
# 54       0.000000            15.443448               42       0.285714
# 53       0.000000            11.422082              175       0.028571
# 52       0.000000            14.807221              104       0.086538
#
#     Sidewalks Per 10k_y  snow_complaints
# 75            12.282497              120
# 48            21.729203              590
# 54            15.443448               42
# 53            11.422082              175
# 52            14.807221              104

# %% [markdown]
# # Export for Analysis

# %%
df_community_summary.to_csv("../../results/dockets-by-community.csv", index= False)
