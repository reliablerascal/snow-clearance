# %%
import pandas as pd

# %%
df = pd.read_csv("../../data/05-finalized/dockets-summary.csv")

# %%
df49 = df[df['ward_1523']=='49']

# %%
df49
# Out:
#           docket      dept    violation_address                 lat  \
# 1     19DS69216L   STRTSAN     1425 W MORSE AVE          42.0074513
# 7     19DS72191L   STRTSAN    1215 W ARTHUR AVE  42.000190450000005
# 9     19DS72216L   STRTSAN    1217 W ARTHUR AVE         42.00023185
# 16    19DS72378L   STRTSAN    1401 W PRATT BLVD           42.005369
# 19    19DS72434L   STRTSAN  6417 N GLENWOOD AVE          41.9986904
# 20    19DS72474L   STRTSAN     1335 W MORSE AVE         42.00773245
# 21    19DS72505L   STRTSAN  6419 N GLENWOOD AVE           41.998781
# 47    20DS72557L   STRTSAN     2053 W HOWARD ST          42.0191085
# 52    20DS72805L   STRTSAN      7464 N CLARK ST          42.0176759
# 56    20DS73871L   STRTSAN    1712 W PRATT BLVD   42.00539654880913
# 58    20DS74580L   STRTSAN     2101 W HOWARD ST         42.01919075
# 64    20DS75561L   STRTSAN     1436 W FARGO AVE          42.0173719
# 75    20DS75693L   STRTSAN     1335 W MORSE AVE         42.00773245
# ...

# %%
len(df49)
# Out:
# 34

# %%
df49.to_csv('../../results/ward49-citations.csv')
