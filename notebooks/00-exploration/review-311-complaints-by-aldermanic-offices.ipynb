# %% [markdown]
# # Review 311 Complaints by Aldermanic Offices

# %%
import pandas as pd

# %%
df = pd.read_csv("../../data/05-finalized/311-complaints-unshoveled.csv")
df.dtypes
# Out:
# SR_NUMBER          object
# SR_SHORT_CODE      object
# CREATED_DATE       object
# STREET_ADDRESS     object
# COMMUNITY_AREA      int64
# WARD                int64
# STATUS             object
# ORIGIN             object
# CLOSED_DATE        object
# LATITUDE          float64
# LONGITUDE         float64
# SR_TYPE            object
# year                int64
# month               int64
# date               object
# season             object
# GEOID               int64
# COMMUNITY_NAME     object
# dtype: object

# %%
df.pivot_table(index='WARD', columns='ORIGIN', aggfunc='count', values='SR_NUMBER')
# Out:
# ORIGIN  Alderman's Office  E-Mail  Generated In House  Internet  \
# WARD
# 1                    30.0     NaN                 NaN     458.0
# 2                    63.0     NaN                 NaN     319.0
# 3                    13.0     NaN                 NaN     114.0
# 4                    12.0     NaN                 NaN     138.0
# 5                     5.0     NaN                 NaN      86.0
# 6                     NaN     NaN                 NaN      72.0
# 7                     1.0     NaN                 NaN      13.0
# 8                     7.0     NaN                 NaN      68.0
# 9                     4.0     NaN                 NaN      14.0
# 10                   11.0     NaN                 NaN      21.0
# 11                   25.0     NaN                 NaN     157.0
# 12                   11.0     NaN                 NaN      65.0
# 13                    NaN     NaN                 NaN      79.0
# 14                   14.0     NaN                 NaN      72.0
# ...
