# %% [markdown]
# # Track 311 Complaints
# 3/6/24
#
# This notebook attempts to track uncleared sidewalk complaints, by matching to citations. I'm looking at one DSS-focused ward (15th) and one CDOT-focused ward (43rd)

# %% [markdown]
# ### key findings
# * ward #s in DSS citations dataset matches what I have in wards I looked up from geocoded dockets
#
# <strong>Ward 15</strong>
# * not accounting for date matches, 10 of 171 dockets matches an address that connects to a 311 complaint
# * only 4 addresses seem to possibly match 311 to dockets, based on identical address and similar create date/violation date (4201 S. Artesian, 4400 S. Washtenaw, 4601 S. Rockwell, 4800 S. Honore)
#
# <strong>Ward 43</strong>
# * not accounting for date matches, 27 of 103 dockets matches an address that connects to a 311 complaint
# * this doesn't show causation though. it could be that cdot/dss was going to ticket these addresses anyway
# * far more matches between 311 and dockets, which suggests that CDOT is the primary (but not necessarily only) agency that handles 311 requests

# %% [markdown]
# # Read Data and Set Up Ward-Level Dataframes

# %%
import pandas as pd

# %% [markdown]
# ### 311 complaints

# %%
df_311 = pd.read_csv("../../data/05-finalized/311-complaints-unshoveled.csv")
df_311.head()
# Out:
#        SR_NUMBER SR_SHORT_CODE         CREATED_DATE          STREET_ADDRESS  \
# 0  SR20-05649092      SWSNOREM  2020-12-17 13:24:37   5200 S BLACKSTONE AVE
# 1  SR21-00001364      SWSNOREM  2021-01-01 11:40:33        66 E CHESTNUT ST
# 2  SR21-00000774      SWSNOREM  2021-01-01 09:11:15       2648 N WHIPPLE ST
# 3  SR20-05723378      SWSNOREM  2020-12-31 07:19:37  5015 N SPRINGFIELD AVE
# 4  SR21-00014080      SWSNOREM  2021-01-04 14:07:09         3757 N BELL AVE
#
#    COMMUNITY_AREA  WARD     STATUS         ORIGIN          CLOSED_DATE  \
# 0              41     4  Completed     Phone Call  2020-12-18 15:12:51
# 1               8    42  Completed  Mobile Device  2021-01-04 14:33:44
# 2              22    32  Completed       Internet  2021-01-06 13:37:58
# 3              14    39  Completed  Mobile Device  2021-01-08 15:30:57
# 4               5    47  Completed       Internet  2021-01-06 11:37:30
#
#     LATITUDE  LONGITUDE                              SR_TYPE  year  month  \
# 0  41.800909 -87.590515  Snow – Uncleared Sidewalk Complaint  2020     12
# 1  41.898399 -87.625723  Snow – Uncleared Sidewalk Complaint  2021      1
# 2  41.930233 -87.703706  Snow – Uncleared Sidewalk Complaint  2021      1
# 3  41.972439 -87.725430  Snow – Uncleared Sidewalk Complaint  2020     12
# 4  41.950316 -87.684472  Snow – Uncleared Sidewalk Complaint  2021      1
#
#          date     season  GEOID   COMMUNITY_NAME
# 0  2020-12-17  2020-2021     41        Hyde Park
# 1  2021-01-01  2020-2021      8  Near North Side
# 2  2021-01-01  2020-2021     22     Logan Square
# 3  2020-12-31  2020-2021     14      Albany Park
# 4  2021-01-04  2020-2021      5     North Center

# %%
df_w15_311 = df_311[df_311['WARD']==15]
len(df_w15_311)
# Out:
# 107

# %% [markdown]
# ### DSS citations

# %%
df_citations = pd.read_csv("../../data/05-finalized/dss-citations.csv")
df_citations.head()
# Out:
#         inspector      violation_code violation_date      docket disposition  \
# 0   Donte Winston            10-8-180     2023-02-02  23DS13151M      Liable
# 1   Donte Winston            10-8-180     2023-02-02  23DS13066M  Not Liable
# 2    Danny Murphy            10-8-180     2023-02-02  23DS04367M     Default
# 3    Danny Murphy            10-8-180     2023-02-02  23DS13237M  Not Liable
# 4  Manuel Heredia  10-8-180; 7-28-060     2023-02-02  23DS09560M     Default
#
#                          citation_address  citation_ward
# 0         2422 W 64 St, Chicago, IL 60629             16
# 1       2435 W 64TH ST, Chicago, IL 60629             16
# 2   7433 N WOLCOTT AVE, Chicago, IL 60626             49
# 3    7418 N PAULINA ST, Chicago, IL 60626             49
# 4  2659 S TRUMBULL AVE, Chicago, IL 60623             22

# %%
df_w15_citations = df_citations[df_citations['citation_ward']==15]
len(df_w15_citations)
# Out:
# 180

# %%
### dockets

# %%
df_dockets = pd.read_csv("../../data/05-finalized/dockets-summary.csv")
df_dockets.head()
# Out:
#        docket     dept    violation_address         lat                long  \
# 0  19DS68300L  STRTSAN   4710 S WESTERN AVE   41.807859  -87.68479703503766
# 1  19DS69216L  STRTSAN     1425 W MORSE AVE  42.0074513         -87.6668285
# 2  19DS70010L  STRTSAN        715 E 47TH ST  41.8093383         -87.6080127
# 3  19DS72153L  STRTSAN  300 W WASHINGTON ST  41.8818694         -87.7401431
# 4  19DS72160L  STRTSAN   6929 N SHERIDAN RD  41.9598134          -87.654693
#
#             community ward_1523 violation_date  n_records
# 0       BRIGHTON PARK        15     2019-11-13          2
# 1         ROGERS PARK        49     2019-11-13          1
# 2     GRAND BOULEVARD         4     2019-11-13          1
# 3  WEST GARFIELD PARK        28     2019-11-12          5
# 4              UPTOWN        46     2019-11-14          1

# %%
df_w15_dockets = df_dockets[df_dockets['ward_1523']=='15']
len(df_w15_dockets)
# Out:
# 171

# %% [markdown]
# ### compare ward assignments in citations vs. dockets
# confirmed, DSS ward assignments match what I have from geocoded dockets for 2015-2019 boundaries

# %%
df_citations_to_dockets = pd.merge(df_w15_citations,df_w15_dockets,on='docket')
len(df_citations_to_dockets)
# Out:
# 161

# %%
df_citations_to_dockets.head()
# Out:
#           inspector         violation_code violation_date_x      docket  \
# 0     Donte Winston               10-8-180       2023-01-31  23DS12474M
# 1     Donte Winston               10-8-180       2023-01-31  23DS12477M
# 2  Francisco Arroyo               10-8-180       2022-02-14  22DS04410M
# 3  Francisco Arroyo  10-8-180; 7-28-750(b)       2022-02-14  22DS04411M
# 4  Francisco Arroyo               10-8-180       2022-02-14  22DS04400M
#
#   disposition                         citation_address  citation_ward  \
# 0      Liable    5514 S WOLCOTT AVE, Chicago, IL 60636             15
# 1     Default    5544 S WOLCOTT AVE, Chicago, IL 60636             15
# 2    Non-Suit      4335 S HONORE ST, Chicago, IL 60609             15
# 3      Liable      4331 S HONORE ST, Chicago, IL 60609             15
# 4    Non-Suit  4400 S WASHTENAW AVE, Chicago, IL 60632             15
#
#       dept     violation_address                 lat                long  \
# 0  STRTSAN    5514 S WOLCOTT AVE          41.7930567  -87.67214746474576
# 1  STRTSAN    5544 S WOLCOTT AVE            41.79226  -87.67208402009223
# 2  STRTSAN      4335 S HONORE ST         41.81477635  -87.67093785010493
# 3  STRTSAN      4331 S HONORE ST  41.815217310702685  -87.67110636944085
# 4  STRTSAN  4400 S WASHTENAW AVE  41.813636849999995  -87.69227153763796
#
#         community ward_1523 violation_date_y  n_records
# 0  WEST ENGLEWOOD        15       2023-01-31          1
# 1  WEST ENGLEWOOD        15       2023-01-31          1
# 2        NEW CITY        15       2022-02-14          2
# 3        NEW CITY        15       2022-02-14          8
# 4   BRIGHTON PARK        15       2022-02-14          1

# %%
df_citations_to_dockets['ward_1523'] = df_citations_to_dockets['ward_1523'].astype(int)

# %%
df_citations_to_dockets[df_citations_to_dockets['ward_1523']!=df_citations_to_dockets['citation_ward']]
# Out:
# Empty DataFrame
# Columns: [inspector, violation_code, violation_date_x, docket, disposition, citation_address, citation_ward, dept, violation_address, lat, long, community, ward_1523, violation_date_y, n_records]
# Index: []

# %% [markdown]
# # match 311 complaints to dockets

# %% [markdown]
# ### exact matches
# try joining dockets because addresses are cleaner

# %%
len(df_w15_311)
# Out:
# 107

# %%
len(df_w15_citations)
# Out:
# 180

# %%
len(df_w15_dockets)
# Out:
# 171

# %%
df_w15_matches = pd.merge(df_w15_dockets,df_w15_311,left_on='violation_address',right_on='STREET_ADDRESS')
len(df_w15_matches)
# Out:
# 21

# %%
df_w15_matches = df_w15_matches[['violation_address','docket','CREATED_DATE','violation_date','docket','ORIGIN']]. \
sort_values(['violation_address','CREATED_DATE','violation_date'])

# %%
#dedup tells us the *maximum* number of matches (but some of these are implausible based on date)
df_w15_matches.drop_duplicates(subset='docket').reset_index()
# Out:
#    index     violation_address      docket         CREATED_DATE  \
# 0      1   4201 S ARTESIAN AVE  20DS75969L  2020-01-20 08:39:31
# 1     20  4400 S WASHTENAW AVE  22DS04400M  2022-02-06 09:57:05
# 2      0    4500 S ROCKWELL ST  20DS75850L  2019-11-12 15:29:11
# 3     12    4532 S WESTERN AVE  22DS03421M  2020-01-22 15:56:58
# 4     15    4600 S WESTERN AVE  22DS03423M  2020-01-01 19:05:36
# 5      6    4601 S ROCKWELL ST  20DS78298L  2020-01-21 09:15:25
# 6     11    4601 S ROCKWELL ST  20DT000874  2020-01-21 09:15:25
# 7     19    4601 S ROCKWELL ST  22DS03968M  2020-01-21 09:15:25
# 8      7      4800 S HONORE ST  20DS78578L  2020-01-23 08:09:03
# 9      2  5600 S WASHTENAW AVE  20DS77767L  2019-11-12 07:42:11
#
#   violation_date      docket         ORIGIN
# 0     2020-01-22  20DS75969L  Mobile Device
# 1     2022-02-14  22DS04400M     Phone Call
# 2     2020-01-22  20DS75850L     Phone Call
# 3     2022-01-06  22DS03421M     Phone Call
# 4     2022-01-06  22DS03423M       Internet
# 5     2020-01-22  20DS78298L       Internet
# 6     2020-02-14  20DT000874       Internet
# 7     2022-01-31  22DS03968M       Internet
# 8     2020-02-27  20DS78578L  Mobile Device
# 9     2020-02-16  20DS77767L     Phone Call

# %% [markdown]
# # 43rd Ward

# %%
df_w43_311 = df_311[df_311['WARD']==43]
len(df_w43_311)
# Out:
# 892

# %%
df_w43_citations = df_citations[df_citations['citation_ward']==43]
len(df_w43_citations)
# Out:
# 2

# %%
df_w43_dockets = df_dockets[df_dockets['ward_1523']=='43']
len(df_w43_dockets)
# Out:
# 103

# %%
df_w43_matches = pd.merge(df_w43_dockets,df_w43_311,left_on='violation_address',right_on='STREET_ADDRESS')
len(df_w43_matches)
# Out:
# 58

# %%
df_w43_matches = df_w43_matches[['violation_address','docket','CREATED_DATE','violation_date','docket','ORIGIN']]. \
sort_values(['violation_address','CREATED_DATE','violation_date'])

# %%
#dedup tells us the *maximum* number of matches (but some of these are implausible based on date)
df_w43_matches.drop_duplicates(subset='docket').reset_index()
