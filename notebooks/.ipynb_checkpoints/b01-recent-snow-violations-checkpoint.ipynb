# %% [markdown]
# <h1>Recent Uncleared Sidewalk Violations, 2023-2024</h1>
# 11 January 2024
#
# This analysis looks at 311 complaints filed as "Snow – Uncleared Sidewalk Complaint," or SWSNOREM in the current (2023-2024) snow season. My previous analysis shows that data seems to be up-to-date within an hour.<br>
# <br>

# %% [markdown]
# <div style="color:red;">
#     <h3>Preliminary Findings</h3>
# <ul>
#     <li>...
# </ul>
#     </div>

# %% [markdown]
# <a name="read"></a>
# # 1. Read Data

# %%
import pandas as pd
import requests
#import datetime as dt #would only need this if I manipulated dates post-API data retrieval

# %%
base_url = "https://data.cityofchicago.org/resource/v6vf-nfxy.json"
select = "SR_NUMBER, SR_SHORT_CODE, CREATED_DATE, STREET_ADDRESS, COMMUNITY_AREA, WARD, STATUS, ORIGIN, CLOSED_DATE, LATITUDE, LONGITUDE, SR_TYPE"
# where = "SR_SHORT_CODE = 'SWSNOREM' AND CREATED_DATE >= '2023-07-01 00:00:00'"
where = "SR_SHORT_CODE = 'SWSNOREM'"
limit = 99999

url = f"{base_url}?$SELECT={select}&$WHERE={where}&$LIMIT={limit}"
print (url)
# Out:
# https://data.cityofchicago.org/resource/v6vf-nfxy.json?$SELECT=SR_NUMBER, SR_SHORT_CODE, CREATED_DATE, STREET_ADDRESS, COMMUNITY_AREA, WARD, STATUS, ORIGIN, CLOSED_DATE, LATITUDE, LONGITUDE, SR_TYPE&$WHERE=SR_SHORT_CODE = 'SWSNOREM'&$LIMIT=99999

# %%
response = requests.get(url)
data = response.json()
print (response)
# Out:
# <Response [200]>

# %%
df=pd.DataFrame(data)
df.head()
# Out:
#        SR_NUMBER SR_SHORT_CODE             CREATED_DATE  \
# 0  SR24-00088099      SWSNOREM  2024-01-15T09:54:58.000
# 1  SR24-00088247      SWSNOREM  2024-01-15T10:12:18.000
# 2  SR22-00180417      SWSNOREM  2022-02-03T07:55:35.000
# 3  SR24-00078179      SWSNOREM  2024-01-12T19:21:49.000
# 4  SR24-00049709      SWSNOREM  2024-01-09T07:26:06.000
#
#           STREET_ADDRESS COMMUNITY_AREA WARD     STATUS         ORIGIN  \
# 0     3161 N LINCOLN AVE              6   32       Open  Mobile Device
# 1  5549 W IRVING PARK RD             15   30       Open       Internet
# 2         1355 E 53RD ST             41    4  Completed       Internet
# 3        5301 N BROADWAY             77   48       Open       Internet
# 4         4337 W 17TH ST             29   24  Completed     Phone Call
#
#        LATITUDE      LONGITUDE                              SR_TYPE  \
# 0  41.939343001     -87.667812  Snow – Uncleared Sidewalk Complaint
# 1  41.953125959  -87.766530726  Snow – Uncleared Sidewalk Complaint
# 2  41.799419522  -87.593072508  Snow – Uncleared Sidewalk Complaint
# 3  41.978322001    -87.6595185  Snow – Uncleared Sidewalk Complaint
# 4  41.857677001      -87.73371  Snow – Uncleared Sidewalk Complaint
#
#                CLOSED_DATE
# 0                      NaN
# 1                      NaN
# 2  2022-02-03T15:03:42.000
# 3                      NaN
# 4  2024-01-09T12:07:07.000

# %% [markdown]
# ### parse dates

# %%
def get_season(month, year):
# Input:
#   month: numeric month of the year (1-12)
#   year (int): 4 digit year
# Returns:
#   season in yy-yy format. E.g. 22-23 means winter 2022-2023, or July 2022 to June 2023.

    if month >= 7:
        return f"{str(year)[-4:]}-{str(year + 1)[-4:]}"
    else:
        return f"{str(year - 1)[-4:]}-{str(year)[-4:]}"

# %%
# format and parse dates
df['CREATED_DATE'] = pd.to_datetime(df['CREATED_DATE'])
df['CLOSED_DATE'] = pd.to_datetime(df['CLOSED_DATE'])
df['year'] = df['CREATED_DATE'].dt.year
df['month'] = df['CREATED_DATE'].dt.month
df['date'] = df['CREATED_DATE'].dt.date
df['season'] = df.apply(lambda row: get_season(row['month'], row['year']), axis=1)
df.head()
# Out:
#        SR_NUMBER SR_SHORT_CODE        CREATED_DATE         STREET_ADDRESS  \
# 0  SR24-00088099      SWSNOREM 2024-01-15 09:54:58     3161 N LINCOLN AVE
# 1  SR24-00088247      SWSNOREM 2024-01-15 10:12:18  5549 W IRVING PARK RD
# 2  SR22-00180417      SWSNOREM 2022-02-03 07:55:35         1355 E 53RD ST
# 3  SR24-00078179      SWSNOREM 2024-01-12 19:21:49        5301 N BROADWAY
# 4  SR24-00049709      SWSNOREM 2024-01-09 07:26:06         4337 W 17TH ST
#
#   COMMUNITY_AREA WARD     STATUS         ORIGIN      LATITUDE      LONGITUDE  \
# 0              6   32       Open  Mobile Device  41.939343001     -87.667812
# 1             15   30       Open       Internet  41.953125959  -87.766530726
# 2             41    4  Completed       Internet  41.799419522  -87.593072508
# 3             77   48       Open       Internet  41.978322001    -87.6595185
# 4             29   24  Completed     Phone Call  41.857677001      -87.73371
#
#                                SR_TYPE         CLOSED_DATE  year  month  \
# 0  Snow – Uncleared Sidewalk Complaint                 NaT  2024      1
# 1  Snow – Uncleared Sidewalk Complaint                 NaT  2024      1
# 2  Snow – Uncleared Sidewalk Complaint 2022-02-03 15:03:42  2022      2
# 3  Snow – Uncleared Sidewalk Complaint                 NaT  2024      1
# 4  Snow – Uncleared Sidewalk Complaint 2024-01-09 12:07:07  2024      1
#
#          date     season
# 0  2024-01-15  2023-2024
# 1  2024-01-15  2023-2024
# 2  2022-02-03  2021-2022
# 3  2024-01-12  2023-2024
# 4  2024-01-09  2023-2024

# %% [markdown]
# ### look at just current year

# %%
df['CREATED_DATE'] = pd.to_datetime(df['CREATED_DATE'])
df = df[(df['season']=='2023-2024')]
len(df)
# Out:
# 308

# %% [markdown]
# ### read community names

# %%
# retrieved on 1/11/24, but 2020 Census Population figures should be static

df_population = pd.read_csv("../data/population_cmap_2022.csv")

# %%
# simplify dataframe to get only essentials
df_population = df_population[['GEOID','GEOG']]
df_population = df_population.rename(columns={'GEOG':'COMMUNITY_NAME'})
df_population.head()
# Out:
#    GEOID  COMMUNITY_NAME
# 0     14     Albany Park
# 1     57  Archer Heights
# 2     34   Armour Square
# 3     70         Ashburn
# 4     71  Auburn Gresham

# %% [markdown]
# ### remove invalid addresses

# %%
df_valid_address = df[(df['STREET_ADDRESS'].isna()==False)
                     & (df['WARD'].isna()==False)
                     & (df['COMMUNITY_AREA'].isna()==False)]
len(df_valid_address)
# Out:
# 307

# %%
# then correct object types to integer
df_valid_address['COMMUNITY_AREA'] = df_valid_address['COMMUNITY_AREA'].astype(int)
df_valid_address['WARD'] = df_valid_address['WARD'].astype(int)
# Out:
# /tmp/ipykernel_983/1714811663.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_valid_address['COMMUNITY_AREA'] = df_valid_address['COMMUNITY_AREA'].astype(int)
# /tmp/ipykernel_983/1714811663.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_valid_address['WARD'] = df_valid_address['WARD'].astype(int)

# %% [markdown]
# ### merge and save

# %%
df_clean = pd.merge(left=df_valid_address,right=df_population,left_on='COMMUNITY_AREA',right_on='GEOID')

# %%
df_clean.to_csv("../data/complaints-2023-24.csv",index=False)

# %% [markdown]
# ### review data

# %%
df_clean.groupby('COMMUNITY_NAME').size().reset_index(name='complaints').sort_values(by='complaints',ascending=False)
# Out:
#             COMMUNITY_NAME  complaints
# 56               West Town          33
# 35         Near North Side          22
# 30            Logan Square          21
# 22           Humboldt Park          18
# 49                  Uptown          13
# 27               Lake View          11
# 8               Bridgeport          11
# 29          Lincoln Square          11
# 39            North Center          10
# 40          North Lawndale          10
# 24             Irving Park           9
# 43            Portage Park           9
# 31         Lower West Side           9
# 28            Lincoln Park           7
# 9          Calumet Heights           6
# 4                   Austin           6
# 5                 Avondale           6
# 25          Jefferson Park           6
# 42            Norwood Park           5
# 15               Edgewater           5
# 46          South Lawndale           5
# 3           Auburn Gresham           4
# 32           McKinley Park           3
# 33             Morgan Park           3
# 2                  Ashburn           3
# 6           Belmont Cragin           3
# 44             Rogers Park           3
# 51         Washington Park           3
# 14      East Garfield Park           3
# 13                 Dunning           3
# 55              West Ridge           3
# 10            Chicago Lawn           3
# 36         Near South Side           3
# 45           South Chicago           2
# 47             South Shore           2
# 52             West Elsdon           2
# 54               West Lawn           2
# 0              Albany Park           2
# 7                  Beverly           2
# 11                Clearing           2
# 1           Archer Heights           2
# 17             Forest Glen           2
# 19         Grand Boulevard           2
# 37          Near West Side           2
# 18               Gage Park           2
# 38                New City           1
# 50      Washington Heights           1
# 12                 Douglas           1
# 53      West Garfield Park           1
# 16               Englewood           1
# 48                The Loop           1
# 20  Greater Grand Crossing           1
# 21                 Hermosa           1
# 23               Hyde Park           1
# 26                 Kenwood           1
# 41              North Park           1
# 34         Mount Greenwood           1
# 57                Woodlawn           1
